# %%
import pandas as pd

# %%
csv_file = 'friends_initial.csv'
df = pd.read_csv(csv_file)
df
# Out:
#                                                  title         rating  \
# 0         S1.E1 ∙ The One Where Monica Gets a Roommate  8.1/10 (9.9K)
# 1         S1.E2 ∙ The One with the Sonogram at the End  7.9/10 (7.7K)
# 2                       S1.E3 ∙ The One with the Thumb  8.0/10 (7.2K)
# 3           S1.E4 ∙ The One with George Stephanopoulos    7.9/10 (7K)
# 4    S1.E5 ∙ The One with the East German Laundry D...    8.3/10 (7K)
# ..                                                 ...            ...
# 229         S10.E13 ∙ The One Where Joey Speaks French  8.3/10 (4.8K)
# 230           S10.E14 ∙ The One with Princess Consuela  8.5/10 (4.6K)
# 231               S10.E15 ∙ The One Where Estelle Dies  8.4/10 (4.3K)
# 232   S10.E16 ∙ The One with Rachel's Going Away Party    8.8/10 (5K)
# 233                             S10.E17 ∙ The Last One   9.6/10 (16K)
#
#                                            description           air_date
# ...
